# %%
# %run ../initEnviroment.py
from plot_data import PlotActivity

# %% [markdown]
# ## Read data

# %% [markdown]
# ### Read labels.txt

# %%
labels = pd.read_csv('../data/RawData/labels.txt', sep=" ", header=None)
labels.columns = ['experiment','person','activity','start','end']

# %%
labels.head()
# Out:
#    experiment  person  activity  start   end
# 0           1       1         5    250  1232
# 1           1       1         7   1233  1392
# 2           1       1         4   1393  2194
# 3           1       1         8   2195  2359
# 4           1       1         5   2360  3374

# %% [markdown]
# Creating titles for the columns

# %% [markdown]
# ### Read the raw data

# %%
import glob
import os

# %%
raw_data_list = os.listdir('../data/RawData/')

# %%
test = pd.read_csv("../data/RawData/acc_exp01_user01.txt", sep=" ", names=['x','y','z'])

# %%
test["time_s"] = test.index/50

# %%
test = test[['time_s','x','y','z']]

# %% [markdown]
# ## Plot activity

# %%
plot = PlotActivity(1,"acc") #experiment 1

# %%
plot.plot_activity(4) #activity 1

# %% [markdown]
# ## Read all

# %%
 if int(self.experiment) < 10:
            self.experiment = '0' + self.experiment


        for i in os.listdir('../data/RawData/'):

# %%
files = np.array(os.listdir('../data/RawData/'))

# %%
        for i in os.listdir('../data/RawData/'):

            if "acc_exp" + self.experiment in i:
                path = "../data/RawData/" + i

# %%
def read_data():
    """Read all data to a dataframe"""
    
    list_df = [] #a list to collect the dataframes
    
    for i in range(1,62):
        
        if i < 10:
            i = '0' + str(i)
        else:
            i = str(i)
            
        for j in os.listdir('../data/RawData/'):
   
            if "acc_exp" + i in j:
                acc_path = "../data/RawData/" + j
                
            elif "gyro_exp" + i in j:
                gyro_path = "../data/RawData/" + j
                    
        acc_df = pd.read_csv(acc_path, sep = " ", names=['acc_x','acc_y','acc_z'])
        gyro_df = pd.read_csv(gyro_path, sep = " ", names=['gyro_x','gyro_y','gyro_z'])
        
        exp_df = pd.concat([acc_df,gyro_df],1)
        exp_df["experiment"] = int(i) #keep track of the experiment
        
        list_df.append(exp_df)
    
    df = pd.concat(list_df)
        
    return df

# %%
df = read_data()

# %%
print("Memory Usage in Mb: ",(df.memory_usage()/1024/1024).sum(),"Mb")
# Out:
# Memory Usage in Mb:  68.528564453125 Mb

# %%
labels
# Out:
#       experiment  person  activity  start    end
# 0              1       1         5    250   1232
# 1              1       1         7   1233   1392
# 2              1       1         4   1393   2194
# 3              1       1         8   2195   2359
# 4              1       1         5   2360   3374
# ...          ...     ...       ...    ...    ...
# 1209          61      30         2  13842  14574
# 1210          61      30         3  14751  15427
# 1211          61      30         2  15588  16319
# 1212          61      30         3  16546  17250
# 1213          61      30         2  17394  18097
#
# [1214 rows x 5 columns]

# %%
test.index.isin(range(250,1232)).sum()
# Out:
# 59902

# %%
test =test.rename(columns={"index": "id"})

# %%
def add_activity_label(df):
    """Add activity labels form the labels dataframe"""
    
    df = df.reset_index()
    df = df.rename(columns={"index": "id"})

    df["activity"] = 0

    for index,row in labels.iterrows():

        df["activity"] = np.where((df.experiment == row["experiment"]) \
                                    & ((df.id >= row["start"]) & (df.id < row["end"])),
                                    row["activity"], df["activity"])
        
    return df

# %%
labeled_df = add_activity_label(df)

# %%
labeled_df["activity"].unique()
# Out:
# array([ 0,  5,  7,  4,  8, 11,  6, 10,  9, 12,  1,  3,  2], dtype=int64)

# %%
labeled_df.head()
# Out:
#    id     acc_x     acc_y     acc_z    gyro_x    gyro_y    gyro_z  experiment  \
# 0   0  0.918056 -0.112500  0.509722 -0.054978 -0.069639 -0.030849           1
# 1   1  0.911111 -0.093056  0.537500 -0.012523  0.019242 -0.038485           1
# 2   2  0.881944 -0.086111  0.513889 -0.023518  0.276417  0.006414           1
# 3   3  0.881944 -0.086111  0.513889 -0.093462  0.367741  0.001222           1
# 4   4  0.879167 -0.100000  0.505556 -0.124311  0.476780 -0.022907           1
#
#    activity
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
range(0,len(df),2000)
# Out:
# 6000

# %%
def create_extended_df(df, window_size, overlap):

    """Create a new df where each block get an id. The blocks are
    part of the original dataframe but each block has a overlap with the previous one."""
    
    k = 0
    overlap = 1 - overlap
    df_list = []
    
    df["block"] = None
    df1 = pd.DataFrame()
    df2 = pd.DataFrame()
    
    for experiment in df.experiment.unique():
        i = 0
        j = window_size
    
        experiment_df = df[df.experiment == experiment]
    
        for _ in range(int(len(experiment_df)/window_size)):

            df2 = experiment_df.iloc[int(i):int(j)].copy()
            df2["block"] = k

            new_df = pd.concat([df1,df2])

            df1 = new_df
            
            i += window_size*overlap
            j += window_size*overlap
            k += 1
            
            df_list.append(new_df)
            
    return new_df

# %%
block_df= create_extended_df(labeled_df,5000,0.5)

# %%
block_df[block_df["block"] == 2]
# Out:
#         id     acc_x     acc_y     acc_z    gyro_x    gyro_y    gyro_z  \
# 5000  5000  0.952778  0.154167  0.315278  0.005498  0.007636 -0.002749
# 5001  5001  0.956944  0.154167  0.312500 -0.001833 -0.003665  0.001527
# 5002  5002  0.962500  0.154167  0.312500  0.006109  0.005803 -0.003971
# 5003  5003  0.962500  0.154167  0.312500  0.002749  0.007636  0.004887
# 5004  5004  0.952778  0.154167  0.312500 -0.001222  0.004581 -0.001527
# ...    ...       ...       ...       ...       ...       ...       ...
# 9995  9995  0.626389 -0.247222  0.019444 -0.561691  1.233337  0.086437
# 9996  9996  0.568056 -0.247222  0.143056 -0.359189  0.547641  0.058948
# 9997  9997  0.663889 -0.219444  0.193056 -0.204334 -0.007941  0.161268
# 9998  9998  0.711111 -0.194444  0.156944 -0.055283 -0.026878  0.262977
# 9999  9999  0.750000 -0.137500  0.108333  0.036957  0.141721  0.246179
#
#       experiment  activity  block
# 5000           1         4      2
# 5001           1         4      2
# 5002           1         4      2
# 5003           1         4      2
# 5004           1         4      2
# ...          ...       ...    ...
# 9995           1         1      2
# 9996           1         1      2
# 9997           1         1      2
# 9998           1         1      2
# 9999           1         1      2
#
# [5000 rows x 10 columns]

# %%
df[df.experiment == 2].iloc[0:10]
# Out:
#       acc_x     acc_y     acc_z    gyro_x    gyro_y    gyro_z  experiment
# 0  0.443056  0.037500  0.888889 -0.036957  0.044593 -0.015272           2
# 1  0.440278  0.041667  0.880556 -0.047342  0.049786 -0.012217           2
# 2  0.451389  0.043056  0.876389 -0.015577  0.006720 -0.016188           2
# 3  0.456944  0.034722  0.888889  0.043066  0.002749 -0.016188           2
# 4  0.447222  0.036111  0.888889  0.053451  0.023518 -0.013744           2
# 5  0.445833  0.045833  0.876389  0.023213  0.037263 -0.030543           2
# 6  0.455556  0.043056  0.890278  0.004581  0.072388 -0.035430           2
# 7  0.455556  0.043056  0.890278  0.017410  0.045204 -0.031460           2
# 8  0.452778  0.045833  0.897222  0.031460 -0.051618 -0.006109           2
# 9  0.452778  0.045833  0.897222  0.036652 -0.049786 -0.007330           2

# %%
df1  = create_extended_df(labeled_df,2000,0.5)

# %%
df1
# Out:
#           id     acc_x     acc_y     acc_z    gyro_x    gyro_y    gyro_z  \
# 0          0  0.918056 -0.112500  0.509722 -0.054978 -0.069639 -0.030849
# 1          1  0.911111 -0.093056  0.537500 -0.012523  0.019242 -0.038485
# 2          2  0.881944 -0.086111  0.513889 -0.023518  0.276417  0.006414
# 3          3  0.881944 -0.086111  0.513889 -0.093462  0.367741  0.001222
# 4          4  0.879167 -0.100000  0.505556 -0.124311  0.476780 -0.022907
# ...      ...       ...       ...       ...       ...       ...       ...
# 10995  10995  1.080556 -0.259722 -0.050000  0.335060 -0.291077 -0.160352
# 10996  10996  1.037500 -0.163889  0.012500  0.250760 -0.875675 -0.268170
# 10997  10997  1.125000 -0.105556 -0.009722  0.194255 -0.836885 -0.266643
# 10998  10998  1.243056 -0.141667 -0.134722 -0.167377 -0.446543 -0.395841
# 10999  10999  1.287500 -0.279167 -0.227778 -0.771217 -0.365297 -0.659429
#
#        experiment  activity  block
# 0               1         0      0
# 1               1         0      0
# 2               1         0      0
# 3               1         0      0
# 4               1         0      0
# ...           ...       ...    ...
# 10995           1         1      9
# 10996           1         1      9
# 10997           1         1      9
# 10998           1         1      9
# 10999           1         1      9
#
# [20000 rows x 10 columns]
